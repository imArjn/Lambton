# %%
print()

# %%
import pandas as pd

# %%
df = pd.read_csv("adult.csv")

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df["age"].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
df["native.country"].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
df["education"].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df["native.country"].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
df.loc[df["native.country"]=="?"] = "unknown"
df[df["native.country"] == "unknown"]
# Out:
#            age workclass   fnlwgt education education.num marital.status  \
# 9      unknown   unknown  unknown   unknown       unknown        unknown
# 18     unknown   unknown  unknown   unknown       unknown        unknown
# 65     unknown   unknown  unknown   unknown       unknown        unknown
# 86     unknown   unknown  unknown   unknown       unknown        unknown
# 87     unknown   unknown  unknown   unknown       unknown        unknown
# ...        ...       ...      ...       ...           ...            ...
# 32459  unknown   unknown  unknown   unknown       unknown        unknown
# 32476  unknown   unknown  unknown   unknown       unknown        unknown
# 32498  unknown   unknown  unknown   unknown       unknown        unknown
# 32515  unknown   unknown  unknown   unknown       unknown        unknown
# 32528  unknown   unknown  unknown   unknown       unknown        unknown
#
#       occupation relationship     race      sex capital.gain capital.loss  \
# ...

# %%
df["native.country"].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# unknown                         583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
df
# Out:
#       age workclass  fnlwgt     education education.num      marital.status  \
# 0      90         ?   77053       HS-grad             9             Widowed
# 1      82   Private  132870       HS-grad             9             Widowed
# 2      66         ?  186061  Some-college            10             Widowed
# 3      54   Private  140359       7th-8th             4            Divorced
# 4      41   Private  264663  Some-college            10           Separated
# ...    ..       ...     ...           ...           ...                 ...
# 32556  22   Private  310152  Some-college            10       Never-married
# 32557  27   Private  257302    Assoc-acdm            12  Married-civ-spouse
# 32558  40   Private  154374       HS-grad             9  Married-civ-spouse
# 32559  58   Private  151910       HS-grad             9             Widowed
# 32560  22   Private  201490       HS-grad             9       Never-married
#
# ...
