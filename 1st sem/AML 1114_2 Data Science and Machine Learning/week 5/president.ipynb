# %%
import pandas as pd
import numpy as np

# %%
pdf = pd.read_csv("polls.csv")

# %%
pdf.shape
# Out:
# (12624, 27)

# %%
pdf.head(5)
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
pdf.columns
# Out:
# Index(['cycle', 'branch', 'type', 'matchup', 'forecastdate', 'state',
#        'startdate', 'enddate', 'pollster', 'grade', 'samplesize', 'population',
#        'poll_wt', 'rawpoll_clinton', 'rawpoll_trump', 'rawpoll_johnson',
#        'rawpoll_mcmullin', 'adjpoll_clinton', 'adjpoll_trump',
#        'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions', 'url',
#        'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %% [markdown]
# ### i) checking whether any columns can be dropped, as there are 27 of them.

# %%
pdf.cycle.unique()

# contains only one unique value thus can be dropped.
# Out:
# array([2016], dtype=int64)

# %%
pdf["branch"].unique()
# Out:
# array(['President'], dtype=object)

# %% [markdown]
# ##### ["cycle","branch","url","poll_id","question_id",] can be dropped.

# %%
# checking which of the columns have just 1 unique value, possible candidate for dropping.
can_be_dropped = []
print("These columns can be dropped: \n")
for col in pdf.columns:
    if  len(pdf[col].unique()) == 1:
        can_be_dropped.append(col)
print(can_be_dropped)
# Out:
# These columns can be dropped:
#
# ['cycle', 'branch', 'matchup', 'forecastdate']

# %%
pdf.nunique()
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %%
for col in pdf.columns:
    print(f"for column named {col} these are the unique values:")
    print(pdf[col].unique())
    print("\n")
# Out:
# for column named cycle these are the unique values:
# [2016]
#
#
# for column named branch these are the unique values:
# ['President']
#
#
# for column named type these are the unique values:
# ['polls-plus' 'now-cast' 'polls-only']
#
#
# for column named matchup these are the unique values:
# ['Clinton vs. Trump vs. Johnson']
#
#
# for column named forecastdate these are the unique values:
# ['11/8/16']
#
#
# for column named state these are the unique values:
# ['U.S.' 'New Mexico' 'Virginia' 'Iowa' 'Wisconsin' 'North Carolina'
#  'Georgia' 'Florida' 'Oregon' 'Ohio' 'South Carolina' 'New York'
#  'Michigan' 'Pennsylvania' 'Missouri' 'New Hampshire' 'Arizona' 'Nevada'
#  'Colorado' 'California' 'Washington' 'Texas' 'Utah' 'Illinois' 'Indiana'
#  'Tennessee' 'Connecticut' 'Massachusetts' 'New Jersey' 'Kansas'
#  'Kentucky' 'Minnesota' 'Oklahoma' 'Maryland' 'Alabama' 'Nebraska'
#  'Louisiana' 'Maine' 'Arkansas' 'Alaska' 'Vermont' 'Idaho' 'Mississippi'
# ...

# %%
# using a method
pdf.apply(pd.unique)
# Out:
# cycle                                                          [2016]
# branch                                                    [President]
# type                               [polls-plus, now-cast, polls-only]
# matchup                               [Clinton vs. Trump vs. Johnson]
# forecastdate                                                [11/8/16]
# state               [U.S., New Mexico, Virginia, Iowa, Wisconsin, ...
# startdate           [11/3/2016, 11/1/2016, 11/2/2016, 11/4/2016, 1...
# enddate             [11/6/2016, 11/7/2016, 11/5/2016, 11/4/2016, 1...
# pollster            [ABC News/Washington Post, Google Consumer Sur...
# grade                       [A+, B, A-, B-, A, nan, B+, C+, C-, C, D]
# samplesize          [2220.0, 26574.0, 2195.0, 3677.0, 16639.0, 129...
# population                                             [lv, rv, a, v]
# poll_wt             [8.720654, 7.628472, 6.424334, 6.087135, 5.316...
# ...

# %% [markdown]
# ### ii) checking if the col value are stored with the desired datatypes. esp the 'date' column

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  object
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  object
#  7   enddate           12624 non-null  object
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
# ...

# %% [markdown]
# ##### we can change the data types for these columns into "date" format
# ##### ['forecastdate','startdate','enddate','createddate','timestamp']

# %% [markdown]
# ##### iv) checking the values within a col and distribution of each value:

# %% [markdown]
# # .value_counts()

# %%
pdf.state.value_counts()
# Out:
# state
# U.S.                    3318
# Florida                  444
# North Carolina           375
# Pennsylvania             375
# Ohio                     345
# New Hampshire            336
# Nevada                   279
# Virginia                 273
# Michigan                 258
# Wisconsin                240
# Georgia                  240
# Colorado                 240
# Arizona                  237
# California               213
# Iowa                     210
# Missouri                 204
# Utah                     198
# New York                 189
# Illinois                 180
# Texas                    174
# Indiana                  168
# New Jersey               162
# Oregon                   162
# Maine                    159
# South Carolina           156
# Washington               153
# Massachusetts            153
# New Mexico               153
# Kansas                   153
# Louisiana                150
# Kentucky                 147
# Idaho                    144
# ...

# %%
# .value_count() to view it in percentage format
pdf.state.value_counts(normalize=True)
# Out:
# state
# U.S.                    0.262833
# Florida                 0.035171
# North Carolina          0.029705
# Pennsylvania            0.029705
# Ohio                    0.027329
# New Hampshire           0.026616
# Nevada                  0.022101
# Virginia                0.021625
# Michigan                0.020437
# Wisconsin               0.019011
# Georgia                 0.019011
# Colorado                0.019011
# Arizona                 0.018774
# California              0.016873
# Iowa                    0.016635
# Missouri                0.016160
# Utah                    0.015684
# New York                0.014971
# Illinois                0.014259
# Texas                   0.013783
# Indiana                 0.013308
# New Jersey              0.012833
# Oregon                  0.012833
# Maine                   0.012595
# South Carolina          0.012357
# Washington              0.012120
# Massachusetts           0.012120
# New Mexico              0.012120
# ...

# %%
pdf[["state","grade"]].head(10)
# Out:
#         state grade
# 0        U.S.    A+
# 1        U.S.     B
# 2        U.S.    A-
# 3        U.S.     B
# 4        U.S.    B-
# 5        U.S.     A
# 6        U.S.    A-
# 7        U.S.    A-
# 8  New Mexico   NaN
# 9        U.S.    A-

# %%
pdf.groupby(["state","grade"]).aggregate({"grade":"count"})
# Out:
#                  grade
# state     grade
# Alabama   A-        42
#           B         45
#           C-        36
# Alaska    B         57
#           B+         6
# ...                ...
# Wisconsin B-        18
#           C-        42
# Wyoming   B         45
#           B-         3
#           C-        36
#
# [321 rows x 1 columns]

# %%
pdf[['state','grade']].value_counts()
# Out:
# state          grade
# U.S.           A-       1215
#                C+        546
#                B         162
#                C-        126
#                A+        114
#                         ...
# Nebraska CD-1  B           3
# Indiana        A           3
# Nebraska CD-2  B           3
# Missouri       A           3
# Mississippi    C           3
# Name: count, Length: 321, dtype: int64

# %%
pdf.aggregate({"grade":"count"})
# Out:
# grade    11337
# dtype: int64

# %%
pdf.groupby(["state"])["grade"].value_counts()
# Out:
# state      grade
# Alabama    B        45
#            A-       42
#            C-       36
# Alaska     B        57
#            C-       36
#                     ..
# Wisconsin  B+       12
#            A+        6
# Wyoming    B        45
#            C-       36
#            B-        3
# Name: count, Length: 321, dtype: int64

# %% [markdown]
# ### dropping columns:

# %%
pdf.drop(columns = ['cycle','branch'], inplace = True)

# %% [markdown]
# #### renaming columns

# %%
# renaming
pdf.rename(columns = {'rawpoll_clinton':'clinton_believers_pc','rawpoll_trump': 'trump_believers_pc','rawpoll_johnson':'johnson_believers_pc','rawpoll_mcmullin':'mcmullin_believers_pc'}, inplace=True)

# %%
pdf.columns
# Out:
# Index(['type', 'matchup', 'forecastdate', 'state', 'startdate', 'enddate',
#        'pollster', 'grade', 'samplesize', 'population', 'poll_wt',
#        'clinton_believers_pc', 'trump_believers_pc', 'johnson_believers_pc',
#        'mcmullin_believers_pc', 'adjpoll_clinton', 'adjpoll_trump',
#        'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions', 'url',
#        'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %% [markdown]
# #### vii) change the datatypes
# ##### we can change the data types for these columns into "date" format
# ##### ['forecastdate','startdate','enddate','createddate','timestamp']

# %%
# method 1
date_cols = ['forecastdate','startdate','enddate','createddate','timestamp']

# %%
pdf[date_cols] = pdf[date_cols].apply(pd.to_datetime)
# Out:
# C:\Users\sthaa\AppData\Local\Temp\ipykernel_7356\294534771.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pdf[date_cols] = pdf[date_cols].apply(pd.to_datetime)

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   type                   12624 non-null  object
#  1   matchup                12624 non-null  object
#  2   forecastdate           12624 non-null  datetime64[ns]
#  3   state                  12624 non-null  object
#  4   startdate              12624 non-null  datetime64[ns]
#  5   enddate                12624 non-null  datetime64[ns]
#  6   pollster               12624 non-null  object
#  7   grade                  11337 non-null  object
#  8   samplesize             12621 non-null  float64
#  9   population             12624 non-null  object
#  10  poll_wt                12624 non-null  float64
#  11  clinton_believers_pc   12624 non-null  float64
#  12  trump_believers_pc     12624 non-null  float64
#  13  johnson_believers_pc   8397 non-null   float64
# ...

# %%
pdf[date_cols].head(5)
# Out:
#   forecastdate  startdate    enddate createddate           timestamp
# 0   2016-11-08 2016-11-03 2016-11-06  2016-11-07 2016-11-08 09:35:33
# 1   2016-11-08 2016-11-01 2016-11-07  2016-11-07 2016-11-08 09:35:33
# 2   2016-11-08 2016-11-02 2016-11-06  2016-11-08 2016-11-08 09:35:33
# 3   2016-11-08 2016-11-04 2016-11-07  2016-11-07 2016-11-08 09:35:33
# 4   2016-11-08 2016-11-03 2016-11-06  2016-11-07 2016-11-08 09:35:33

# %%
#method 2
ppdf = pd.read_csv("polls.csv",parse_dates= date_cols)
# Out:
# C:\Users\sthaa\AppData\Local\Temp\ipykernel_7356\2275584023.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ppdf = pd.read_csv("polls.csv",parse_dates= date_cols)

# %%
ppdf[date_cols].head(5)
# Out:
#   forecastdate  startdate    enddate createddate           timestamp
# 0   2016-11-08 2016-11-03 2016-11-06  2016-11-07 2016-11-08 09:35:33
# 1   2016-11-08 2016-11-01 2016-11-07  2016-11-07 2016-11-08 09:35:33
# 2   2016-11-08 2016-11-02 2016-11-06  2016-11-08 2016-11-08 09:35:33
# 3   2016-11-08 2016-11-04 2016-11-07  2016-11-07 2016-11-08 09:35:33
# 4   2016-11-08 2016-11-03 2016-11-06  2016-11-07 2016-11-08 09:35:33
