# %%
import pandas as pd
# Out:
# C:\Users\sthaa\AppData\Local\Temp\ipykernel_16248\2565880256.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("2_customers.csv")
#df = pd.read_csv("E:\\Lambton\\AML 1114 Data Science and Machine Learning\\week 1\\2_customers.csv")

# %%
df
# Out:
#       id           cust_name  num_products province  len_relationship  \
# 0   1001      Johnny Awesome             3       ON                 1
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df.shape
# Out:
# (13, 6)

# %%
df.head()
# Out:
#      id       cust_name  num_products province  len_relationship  \
# 0  1001  Johnny Awesome             3       ON                 1
# 1  1002      Bob Marley             4       ON                 1
# 2  1004    Taylor Swift             2       AB                 2
# 3  1101      James Dean             3       BC                 3
# 4  1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df.tail(3)
# Out:
#       id          cust_name  num_products province  len_relationship  \
# 10  1008     Robert Optimus             3       MB                10
# 11  1585       Steven Prime             5       AB                 2
# 12  1475  Stephanie Element             2       ON                 5
#
#        cust_category
# 10               hnw
# 11            wealth
# 12  personal_banking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                13 non-null     int64
#  1   cust_name         13 non-null     object
#  2   num_products      13 non-null     int64
#  3   province          13 non-null     object
#  4   len_relationship  13 non-null     int64
#  5   cust_category     13 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 756.0+ bytes

# %%
df.describe()
# Out:
#                 id  num_products  len_relationship
# count    13.000000     13.000000         13.000000
# mean   1161.076923      3.153846          3.461538
# std     206.590360      1.344504          2.366974
# min    1001.000000      1.000000          1.000000
# 25%    1005.000000      2.000000          2.000000
# 50%    1014.000000      3.000000          3.000000
# 75%    1285.000000      4.000000          4.000000
# max    1585.000000      5.000000         10.000000

# %%
df.set_index('id',inplace=False)
# Out:
#                cust_name  num_products province  len_relationship  \
# id
# 1001      Johnny Awesome             3       ON                 1
# 1002          Bob Marley             4       ON                 1
# 1004        Taylor Swift             2       AB                 2
# 1101          James Dean             3       BC                 3
# 1006       Stephen Smith             5       ON                 4
# 1014       Delilah Avery             2       AB                 3
# 1254        Johnson Cory             1       AB                 4
# 1285          Maria Alva             5       ON                 2
# 1354        Jessica Fast             4       BC                 5
# 1005  Mariah Anita Smith             2       BC                 3
# 1008      Robert Optimus             3       MB                10
# 1585        Steven Prime             5       AB                 2
# 1475   Stephanie Element             2       ON                 5
#
#          cust_category
# id
# ...

# %%
df2 = df.rename(columns={'id':'cust_id'})

# %%
df2.head()
# Out:
#    cust_id       cust_name  num_products province  len_relationship  \
# 0     1001  Johnny Awesome             3       ON                 1
# 1     1002      Bob Marley             4       ON                 1
# 2     1004    Taylor Swift             2       AB                 2
# 3     1101      James Dean             3       BC                 3
# 4     1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df.head()
# Out:
#      id       cust_name  num_products province  len_relationship  \
# 0  1001  Johnny Awesome             3       ON                 1
# 1  1002      Bob Marley             4       ON                 1
# 2  1004    Taylor Swift             2       AB                 2
# 3  1101      James Dean             3       BC                 3
# 4  1006   Stephen Smith             5       ON                 4
#
#       cust_category
# 0            wealth
# 1  personal_banking
# 2               hnw
# 3            wealth
# 4               hnw

# %%
df2.set_index('cust_id',inplace = True)

# %%
df2.head()
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2.shape
# Out:
# (13, 5)

# %%
df.shape
# Out:
# (13, 6)

# %%
df2.axes
# axis = 0 ==> refers to the Rows
# axis = 1 ==> refers to the columns
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='cust_id'),
#  Index(['cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
#alternative way of renaming cols, rather than using 'df.rename()'
df2.columns = ['Cust_name', 'Num_products', 'Province', 'Len_relationship',
        'Cust_category']
df2.head()
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             Cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df
# Out:
#       id           cust_name  num_products province  len_relationship  \
# 0   1001      Johnny Awesome             3       ON                 1
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1008         Robert Optimus             3       MB                10
# 1585           Steven Prime             5       AB                 2
# ...

# %%
#sorting the values of the Axes

# %%
#sort the rows- lavbels:
df2.sort_index(axis=0, ascending= False)
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# cust_id
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
# 1354           Jessica Fast             4       BC                 5
# 1285             Maria Alva             5       ON                 2
# 1254           Johnson Cory             1       AB                 4
# 1101             James Dean             3       BC                 3
# 1014          Delilah Avery             2       AB                 3
# 1008         Robert Optimus             3       MB                10
# 1006          Stephen Smith             5       ON                 4
# 1005     Mariah Anita Smith             2       BC                 3
# 1004           Taylor Swift             2       AB                 2
# 1002             Bob Marley             4       ON                 1
# ...

# %%
df2.sort_index(axis=1, ascending=True)
# Out:
#             Cust_category           Cust_name  Len_relationship  Num_products  \
# cust_id
# 1001               wealth      Johnny Awesome                 1             3
# 1002     personal_banking          Bob Marley                 1             4
# 1004                  hnw        Taylor Swift                 2             2
# 1101               wealth          James Dean                 3             3
# 1006                  hnw       Stephen Smith                 4             5
# 1014     personal_banking       Delilah Avery                 3             2
# 1254                  hnw        Johnson Cory                 4             1
# 1285               wealth          Maria Alva                 2             5
# 1354     personal_banking        Jessica Fast                 5             4
# 1005     personal_banking  Mariah Anita Smith                 3             2
# 1008                  hnw      Robert Optimus                10             3
# ...

# %%
#rename the index name
df2.index.names = ['Cust_id']
df2.head()
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1008         Robert Optimus             3       MB                10
# 1585           Steven Prime             5       AB                 2
# ...

# %%
df2['Cust_name'] #series 1D
# Out:
# Cust_id
# 1001        Johnny Awesome
# 1002            Bob Marley
# 1004          Taylor Swift
# 1101            James Dean
# 1006         Stephen Smith
# 1014         Delilah Avery
# 1254          Johnson Cory
# 1285            Maria Alva
# 1354          Jessica Fast
# 1005    Mariah Anita Smith
# 1008        Robert Optimus
# 1585          Steven Prime
# 1475     Stephanie Element
# Name: Cust_name, dtype: object

# %%
df2[['Cust_name','Len_relationship']] #DF output 2D
# Out:
#                   Cust_name  Len_relationship
# Cust_id
# 1001         Johnny Awesome                 1
# 1002             Bob Marley                 1
# 1004           Taylor Swift                 2
# 1101             James Dean                 3
# 1006          Stephen Smith                 4
# 1014          Delilah Avery                 3
# 1254           Johnson Cory                 4
# 1285             Maria Alva                 2
# 1354           Jessica Fast                 5
# 1005     Mariah Anita Smith                 3
# 1008         Robert Optimus                10
# 1585           Steven Prime                 2
# 1475      Stephanie Element                 5

# %% [markdown]
# ## Access rows using 'df.loc[]' and 'df.iloc[]

# %%
df2.loc[1002]
# Out:
# Cust_name                 Bob Marley
# Num_products                       4
# Province                          ON
# Len_relationship                   1
# Cust_category       personal_banking
# Name: 1002, dtype: object

# %%
df2.iloc[1]
# Out:
# Cust_name                 Bob Marley
# Num_products                       4
# Province                          ON
# Len_relationship                   1
# Cust_category       personal_banking
# Name: 1002, dtype: object

# %%
df2.iloc[[2,3]]
# Out:
#             Cust_name  Num_products Province  Len_relationship Cust_category
# Cust_id
# 1004     Taylor Swift             2       AB                 2           hnw
# 1101       James Dean             3       BC                 3        wealth

# %%
df2.iloc[0::2]
# Out:
#                  Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001        Johnny Awesome             3       ON                 1
# 1004          Taylor Swift             2       AB                 2
# 1006         Stephen Smith             5       ON                 4
# 1254          Johnson Cory             1       AB                 4
# 1354          Jessica Fast             4       BC                 5
# 1008        Robert Optimus             3       MB                10
# 1475     Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1004                  hnw
# 1006                  hnw
# 1254                  hnw
# 1354     personal_banking
# 1008                  hnw
# 1475     personal_banking

# %% [markdown]
# ## Access the range of rows from Taylor Swift to Delilah Avery

# %%
df2.loc[1004:1014]
# Out:
#              Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1004      Taylor Swift             2       AB                 2
# 1101        James Dean             3       BC                 3
# 1006     Stephen Smith             5       ON                 4
# 1014     Delilah Avery             2       AB                 3
#
#             Cust_category
# Cust_id
# 1004                  hnw
# 1101               wealth
# 1006                  hnw
# 1014     personal_banking

# %%
df2.iloc[2:6]
# Out:
#              Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1004      Taylor Swift             2       AB                 2
# 1101        James Dean             3       BC                 3
# 1006     Stephen Smith             5       ON                 4
# 1014     Delilah Avery             2       AB                 3
#
#             Cust_category
# Cust_id
# 1004                  hnw
# 1101               wealth
# 1006                  hnw
# 1014     personal_banking

# %%
df2.head()
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
df2.loc[df2.Cust_name=='Bob Marley']
# Out:
#           Cust_name  Num_products Province  Len_relationship     Cust_category
# Cust_id
# 1002     Bob Marley             4       ON                 1  personal_banking

# %%
df2.loc[df2.Cust_name=='Bob Marley',['Cust_name','Province']]
# Out:
#           Cust_name Province
# Cust_id
# 1002     Bob Marley       ON

# %%
df2.head(8)
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
# 1014      Delilah Avery             2       AB                 3
# 1254       Johnson Cory             1       AB                 4
# 1285         Maria Alva             5       ON                 2
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1285               wealth

# %%
df2.loc[1004:1014,['Cust_name','Num_products']]
df2.iloc[2:6,0:2]
# Out:
#              Cust_name  Num_products
# Cust_id
# 1004      Taylor Swift             2
# 1101        James Dean             3
# 1006     Stephen Smith             5
# 1014     Delilah Avery             2

# %%
#Find the cust_category for Steven Prime

# %%
#Find the cust_category for Steven Prime
df2.loc[df2.Cust_name=='Steven Prime',['Cust_name','Cust_category']]
# Out:
#             Cust_name Cust_category
# Cust_id
# 1585     Steven Prime        wealth

# %%
#Find the cust_category for Steven Prime
df2[df2.Cust_name == 'Steven Prime'][['Cust_name','Cust_category']]
# Out:
#             Cust_name Cust_category
# Cust_id
# 1585     Steven Prime        wealth

# %%
df2.loc[df2.Cust_name == 'Steven Prime'].Cust_category.item()
# Out:
# 'wealth'

# %%
df2[df2['Cust_name']=="Steven Prime"]['Cust_category']
# Out:
# Cust_id
# 1585    wealth
# Name: Cust_category, dtype: object

# %%
# For Steven Prime, display the cust_name and cust_category
#without using loc
df2[df2['Cust_name']=="Steven Prime"][['Cust_name','Cust_category']]
# Out:
#             Cust_name Cust_category
# Cust_id
# 1585     Steven Prime        wealth

# %% [markdown]
# ### (v) Filtering

# %%
#Display the rows for customers belonging to Alberta
df2[df2.Province == 'AB']
# Out:
#              Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1004      Taylor Swift             2       AB                 2
# 1014     Delilah Avery             2       AB                 3
# 1254      Johnson Cory             1       AB                 4
# 1585      Steven Prime             5       AB                 2
#
#             Cust_category
# Cust_id
# 1004                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1585               wealth

# %%
#customers belonging to either ONtario or BC
df2[(df2.Province == "ON") | (df2.Province == "BC")]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %%
#customers belonging to either ONtario or BC
df2[(df2['Province'] == 'ON') | (df2['Province'] == 'BC')]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %%
#Customers who have 1,2 or 5 products:
df2[(df2.Num_products == 1) | (df2.Num_products == 2) | (df2.Num_products == 5)]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1004           Taylor Swift             2       AB                 2
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1005     Mariah Anita Smith             2       BC                 3
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1004                  hnw
# 1006                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1285               wealth
# 1005     personal_banking
# 1585               wealth
# 1475     personal_banking

# %%
#Customers who have 1,2 or 5 products:
df2[df2.Num_products.isin([1,2,5])]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1004           Taylor Swift             2       AB                 2
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1005     Mariah Anita Smith             2       BC                 3
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1004                  hnw
# 1006                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1285               wealth
# 1005     personal_banking
# 1585               wealth
# 1475     personal_banking

# %%
#customers belonging to either ONtario or BC
df2[df2['Province'].isin(['ON','BC'])]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %%
#
df2[df2.Cust_name.isin(['Bob Marley','Stephen Smith','Robert Optimus','Jessica Fast'])]
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1002         Bob Marley             4       ON                 1
# 1006      Stephen Smith             5       ON                 4
# 1354       Jessica Fast             4       BC                 5
# 1008     Robert Optimus             3       MB                10
#
#             Cust_category
# Cust_id
# 1002     personal_banking
# 1006                  hnw
# 1354     personal_banking
# 1008                  hnw

# %%
# customers having atleast 2 products:
df2[df2.Num_products >= 2]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1008         Robert Optimus             3       MB                10
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# ...

# %%
#Customer who DO NOT have 2 products
df2[df2.Num_products != 2]
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
# 1254       Johnson Cory             1       AB                 4
# 1285         Maria Alva             5       ON                 2
# 1354       Jessica Fast             4       BC                 5
# 1008     Robert Optimus             3       MB                10
# 1585       Steven Prime             5       AB                 2
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1254                  hnw
# 1285               wealth
# 1354     personal_banking
# 1008                  hnw
# 1585               wealth

# %%
#Customers with cust_id 1006 and 1475
df2[df2.index.isin([1006, 1475])]
# Out:
#                  Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1006         Stephen Smith             5       ON                 4
# 1475     Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1006                  hnw
# 1475     personal_banking

# %%
df2[(df2.index == 1006) | (df2.index == 1475)]
# Out:
#                  Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1006         Stephen Smith             5       ON                 4
# 1475     Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1006                  hnw
# 1475     personal_banking

# %% [markdown]
# ### Customers whose number of Products is anywhere between 2 to 8

# %%
#customers whose number of products is anywhere between 2 to 8:
df2[df2.Num_products.isin(range(2,8+1))]
# Out:
#                   Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1014          Delilah Avery             2       AB                 3
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1008         Robert Optimus             3       MB                10
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# ...

# %%
#customers whose names begin with 'J'
df2[df2.Cust_name.str.startswith('J')]
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1101         James Dean             3       BC                 3
# 1254       Johnson Cory             1       AB                 4
# 1354       Jessica Fast             4       BC                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1101               wealth
# 1254                  hnw
# 1354     personal_banking

# %%
#display the province, for customers whose names contain "m". The position of "m" could be anywhere in the name
df2[df2.Cust_name.str.contains("m") | df2.Cust_name.str.contains("M")][['Province']]
# Out:
#         Province
# Cust_id
# 1001          ON
# 1002          ON
# 1101          BC
# 1006          ON
# 1285          ON
# 1005          BC
# 1008          MB
# 1585          AB
# 1475          ON

# %%
#display the province, for customers whose names contain "m". The position of "m" could be anywhere in the name
df2[df2.Cust_name.str.lower().str.contains("m")][['Province']]
# Out:
#         Province
# Cust_id
# 1001          ON
# 1002          ON
# 1101          BC
# 1006          ON
# 1285          ON
# 1005          BC
# 1008          MB
# 1585          AB
# 1475          ON

# %%
#CUSTOMER with longest length of relationship
maxlen = df2.Len_relationship.max()
df2[df2.Len_relationship == maxlen]
# Out:
#               Cust_name  Num_products Province  Len_relationship Cust_category
# Cust_id
# 1008     Robert Optimus             3       MB                10           hnw

# %%
df2.Len_relationship.idxmax()
# Out:
# 1008

# %%
#CUSTOMER with longest length of relationship
df2[df2.index == df2.Len_relationship.idxmax()]
# Out:
#               Cust_name  Num_products Province  Len_relationship Cust_category
# Cust_id
# 1008     Robert Optimus             3       MB                10           hnw

# %%
#CUSTOMER with longest length of relationship
df2.sort_values(by = 'Len_relationship', ascending = False).iloc[[0]]
# Out:
#               Cust_name  Num_products Province  Len_relationship Cust_category
# Cust_id
# 1008     Robert Optimus             3       MB                10           hnw

# %%
df2.drop(["Num_products"], axis= 1 ,inplace= False)
# Out:
#                   Cust_name Province  Len_relationship     Cust_category
# Cust_id
# 1001         Johnny Awesome       ON                 1            wealth
# 1002             Bob Marley       ON                 1  personal_banking
# 1004           Taylor Swift       AB                 2               hnw
# 1101             James Dean       BC                 3            wealth
# 1006          Stephen Smith       ON                 4               hnw
# 1014          Delilah Avery       AB                 3  personal_banking
# 1254           Johnson Cory       AB                 4               hnw
# 1285             Maria Alva       ON                 2            wealth
# 1354           Jessica Fast       BC                 5  personal_banking
# 1005     Mariah Anita Smith       BC                 3  personal_banking
# 1008         Robert Optimus       MB                10               hnw
# 1585           Steven Prime       AB                 2            wealth
# ...

# %% [markdown]
# #### (VIII) Dropping Cols

# %%
df2.head()
# Out:
#               Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1004       Taylor Swift             2       AB                 2
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth
# 1006                  hnw

# %%
#Q1. What is the avg length of banking relationship per province?

# %%
df2.Province.unique()
# Out:
# array(['ON', 'AB', 'BC', 'MB'], dtype=object)

# %%
df2.groupby("Province")["Len_relationship"].mean()
# Out:
# Province
# AB     2.750000
# BC     3.666667
# MB    10.000000
# ON     2.600000
# Name: Len_relationship, dtype: float64

# %%
pr_grouped = df2.groupby("Province")
pr_grouped.groups
# Out:
# {'AB': [1004, 1014, 1254, 1585], 'BC': [1101, 1354, 1005], 'MB': [1008], 'ON': [1001, 1002, 1006, 1285, 1475]}

# %%
pr_grouped.get_group("ON")
# Out:
#                  Cust_name  Num_products Province  Len_relationship  \
# Cust_id
# 1001        Johnny Awesome             3       ON                 1
# 1002            Bob Marley             4       ON                 1
# 1006         Stephen Smith             5       ON                 4
# 1285            Maria Alva             5       ON                 2
# 1475     Stephanie Element             2       ON                 5
#
#             Cust_category
# Cust_id
# 1001               wealth
# 1002     personal_banking
# 1006                  hnw
# 1285               wealth
# 1475     personal_banking

# %%
# min max avg length of banking relationship per province?

# %%
df3 = df2.groupby('Province')['Len_relationship'].describe()
df3[["mean","max","min"]]
# Out:
#                mean   max   min
# Province
# AB         2.750000   4.0   2.0
# BC         3.666667   5.0   3.0
# MB        10.000000  10.0  10.0
# ON         2.600000   5.0   1.0

# %%
df2.groupby("Province")["Len_relationship"].aggregate(["mean","max","min","sum"])
# Out:
#                mean  max  min  sum
# Province
# AB         2.750000    4    2   11
# BC         3.666667    5    3   11
# MB        10.000000   10   10   10
# ON         2.600000    5    1   13

# %%
trans_df = pd.read_csv("transactions.csv")

# %%
trans_df.head()
# Out:
#    id  customer_id txn_type  txn_total
# 0   1         1001    Debit     165.78
# 1   2         1001   Credit      42.10
# 2   4         1001   Credit     103.03
# 3   5         1001   Credit      56.60
# 4   6         1002    Debit     214.34

# %%
renamed = trans_df.rename(columns={"customer_id":"Cust_id"},inplace = False)
another = renamed.join(df2,on="Cust_id",how = "inner")
another
# Out:
#     id  Cust_id txn_type  txn_total           Cust_name  Num_products  \
# 0    1     1001    Debit     165.78      Johnny Awesome             3
# 1    2     1001   Credit      42.10      Johnny Awesome             3
# 2    4     1001   Credit     103.03      Johnny Awesome             3
# 3    5     1001   Credit      56.60      Johnny Awesome             3
# 4    6     1002    Debit     214.34          Bob Marley             4
# 5    7     1002     Cash     115.69          Bob Marley             4
# 6    8     1002    Debit      21.37          Bob Marley             4
# 7    9     1004     Cash     227.58        Taylor Swift             2
# 8   10     1004   Credit       5.92        Taylor Swift             2
# 9   11     1006    Debit     225.89       Stephen Smith             5
# 10  12     1014     Cash      67.96       Delilah Avery             2
# 11  13     1254    Debit     235.79        Johnson Cory             1
# ...

# %%
trans_df.merge(df2, left_on="customer_id", right_on="Cust_id")
# Out:
#     id  customer_id txn_type  txn_total           Cust_name  Num_products  \
# 0    1         1001    Debit     165.78      Johnny Awesome             3
# 1    2         1001   Credit      42.10      Johnny Awesome             3
# 2    4         1001   Credit     103.03      Johnny Awesome             3
# 3    5         1001   Credit      56.60      Johnny Awesome             3
# 4    6         1002    Debit     214.34          Bob Marley             4
# 5    7         1002     Cash     115.69          Bob Marley             4
# 6    8         1002    Debit      21.37          Bob Marley             4
# 7    9         1004     Cash     227.58        Taylor Swift             2
# 8   10         1004   Credit       5.92        Taylor Swift             2
# 9   11         1006    Debit     225.89       Stephen Smith             5
# 10  12         1014     Cash      67.96       Delilah Avery             2
# 11  13         1254    Debit     235.79        Johnson Cory             1
# ...

# %%
trans_df.to_csv("merged_custTrans.csv")

# %%
# Q3 {Min,Max,Avg} amount spent in a transaction per customer?

# %%
trans_df.groupby("customer_id")["txn_total"].describe()[["mean","max","min"]]
# Out:
#                    mean     max     min
# customer_id
# 1001          91.877500  165.78   42.10
# 1002         117.133333  214.34   21.37
# 1004         116.750000  227.58    5.92
# 1005         267.230000  403.62  122.06
# 1006         225.890000  225.89  225.89
# 1008         199.730000  242.73  166.44
# 1014         233.476667  449.39   67.96
# 1254         168.753333  255.21   15.26
# 1285         270.466667  393.91  160.89
# 1354         303.290000  438.29   94.32
# 1475         227.466667  328.72   87.38
# 1585         286.183333  320.40  230.24

# %%
trans_df.groupby("customer_id")["txn_total"].aggregate(["mean","max","min"])
# Out:
#                    mean     max     min
# customer_id
# 1001          91.877500  165.78   42.10
# 1002         117.133333  214.34   21.37
# 1004         116.750000  227.58    5.92
# 1005         267.230000  403.62  122.06
# 1006         225.890000  225.89  225.89
# 1008         199.730000  242.73  166.44
# 1014         233.476667  449.39   67.96
# 1254         168.753333  255.21   15.26
# 1285         270.466667  393.91  160.89
# 1354         303.290000  438.29   94.32
# 1475         227.466667  328.72   87.38
# 1585         286.183333  320.40  230.24

# %%
trans_df.isna().sum()
# Out:
# id             0
# customer_id    0
# txn_type       0
# txn_total      0
# dtype: int64

# %%
another
# Out:
#     id  Cust_id txn_type  txn_total           Cust_name  Num_products  \
# 0    1     1001    Debit     165.78      Johnny Awesome             3
# 1    2     1001   Credit      42.10      Johnny Awesome             3
# 2    4     1001   Credit     103.03      Johnny Awesome             3
# 3    5     1001   Credit      56.60      Johnny Awesome             3
# 4    6     1002    Debit     214.34          Bob Marley             4
# 5    7     1002     Cash     115.69          Bob Marley             4
# 6    8     1002    Debit      21.37          Bob Marley             4
# 7    9     1004     Cash     227.58        Taylor Swift             2
# 8   10     1004   Credit       5.92        Taylor Swift             2
# 9   11     1006    Debit     225.89       Stephen Smith             5
# 10  12     1014     Cash      67.96       Delilah Avery             2
# 11  13     1254    Debit     235.79        Johnson Cory             1
# ...

# %%
another.to_csv("merged_custTrans1.csv",index=False)
